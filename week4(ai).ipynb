# %%
# !pip install tensorflow pillow

# %%
import numpy as np
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
from google.colab import files

# %%
print("Loading AI Model...")

model = MobileNetV2(weights="imagenet")

print("✅ AI Model Loaded Successfully!")
# Out:
# Loading AI Model...
# ...
# 14536120/14536120 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ✅ AI Model Loaded Successfully!

# %%
print("\nUpload an Image")

uploaded = files.upload()
# Out:
# Upload an Image
#      <input type="file" id="files-c9b6e631-1d52-43cc-925d-a4f93407814a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c9b6e631-1d52-43cc-925d-a4f93407814a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
img_path = list(uploaded.keys())[0]

img = image.load_img(img_path, target_size=(224,224))

img_array = image.img_to_array(img)

img_array = np.expand_dims(img_array, axis=0)

img_array = preprocess_input(img_array)

# %%
prediction = model.predict(img_array)

result = decode_predictions(prediction, top=1)[0]

food = result[0][1]
confidence = result[0][2] * 100
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 890ms/step
# ...
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
food_info = {

    "pizza":{
        "Calories":"285 kcal",
        "Cuisine":"Italian",
        "Description":"Pizza is a baked dish topped with cheese, vegetables or meat.",
        "Drink":"Coke"
    },

    "cheeseburger":{
        "Calories":"354 kcal",
        "Cuisine":"American",
        "Description":"A cheeseburger is a burger topped with cheese.",
        "Drink":"Cold Coffee"
    },

    "hotdog":{
        "Calories":"290 kcal",
        "Cuisine":"American",
        "Description":"A hotdog is a sausage served inside a bun.",
        "Drink":"Soft Drink"
    },

    "dough":{
        "Calories":"180 kcal",
        "Cuisine":"Bakery",
        "Description":"Fresh dough used for baking.",
        "Drink":"Tea"
    },

    "bagel":{
        "Calories":"250 kcal",
        "Cuisine":"American",
        "Description":"A round bread roll with a chewy texture.",
        "Drink":"Coffee"
    }
}

# %%
print("\n")
print("="*50)
print("🍽 AI IMAGE RECOGNITION RESULT")
print("="*50)

print("Detected Object :", food.title())
print("Confidence      :", round(confidence,2),"%")
# Out:
# ...
# 🍽 AI IMAGE RECOGNITION RESULT
# ...
# Detected Object : Pizza
# Confidence      : 89.77 %

# %%
if food in food_info:

    print("\n🍴 Food Information")
    print("-"*50)

    print("Food Name   :", food.title())
    print("Calories    :", food_info[food]["Calories"])
    print("Cuisine     :", food_info[food]["Cuisine"])
    print("Description :", food_info[food]["Description"])
    print("Best Drink  :", food_info[food]["Drink"])

else:

    print("\nSorry!")
    print("Food details are not available in the database.")
    print("\n")
print("="*50)
print("Thank You for Using AI Image Recognition")
print("="*50)
# Out:
# 🍴 Food Information
# --------------------------------------------------
# Food Name   : Pizza
# Calories    : 285 kcal
# Cuisine     : Italian
# Description : Pizza is a baked dish topped with cheese, vegetables or meat.
# Best Drink  : Coke
# ...
# Thank You for Using AI Image Recognition
# ...
